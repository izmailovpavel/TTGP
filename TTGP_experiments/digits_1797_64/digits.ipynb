# %%
import numpy as np
from sklearn.datasets import load_digits
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
digits = load_digits()

# %%
digits.data.shape
# Out:
# (1797, 64)

# %%
x = digits.data
y = digits.target

# %%
x_tr = np.copy(x)
y_tr = np.copy(y)
np.random.shuffle([x_tr, y_tr])

# %%
i = 29
img = x[i]
plt.imshow(img.reshape(8, 8), interpolation='Nearest', cmap='gray')
print(y_tr[i])
# Out:
# 9

# %%
n_tr = int(y_tr.size * 0.8)
x_te = x_tr[n_tr:, :]
y_te = y_tr[n_tr:]
x_tr = x_tr[:n_tr, :]
y_tr = y_tr[:n_tr]

# %%
scaler_x = StandardScaler()
scaler_y = StandardScaler()
x_tr = scaler_x.fit_transform(x_tr)
x_te = scaler_x.transform(x_te)
y_tr_reg = scaler_y.fit_transform(y_tr)
y_te_reg = scaler_y.transform(y_te)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/preprocessing/data.py:586: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/preprocessing/data.py:649: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
# np.save('data_reg/x_tr.npy', x_tr)
# np.save('data_reg/x_te.npy', x_te)
# np.save('data_reg/y_tr.npy', y_tr_reg)
# np.save('data_reg/y_te.npy', y_te_reg)

# %%
# np.save('data_class/x_tr.npy', x_tr)
# np.save('data_class/x_te.npy', x_te)
# np.save('data_class/y_tr.npy', y_tr)
# np.save('data_class/y_te.npy', y_te)

# %% [markdown]
# ## PCA vizualization

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
x_2d = pca.fit_transform(x)

# %%
plt.clf()
zeros = x_2d[y == 0]
ones = x_2d[y == 1]
twos = x_2d[y == 2]
threes = x_2d[y == 3]
fives = x_2d[y == 5]
nines = x_2d[y == 9]

plt.plot(zeros[:, 0], zeros[:, 1], 'ro', label='0')
plt.plot(ones[:, 0], ones[:, 1], 'bo', label='1')
plt.plot(twos[:, 0], twos[:, 1], 'yo', label='2')
plt.plot(threes[:, 0], threes[:, 1], 'go', label='3')
plt.plot(fives[:, 0], fives[:, 1], 'mo', label='3')
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')
plt.legend()

# %% [markdown]
# 3d for comparison

# %%
pca = PCA(n_components=3)
x_tr_3d = pca.fit_transform(x_tr)
x_te_3d = pca.transform(x_te)
np.save('../../data/temp/x_tr.npy', x_tr_3d)
np.save('../../data/temp/x_te.npy', x_te_3d)
np.save('../../data/temp/y_tr.npy', y_tr)
np.save('../../data/temp/y_te.npy', y_te)

# %% [markdown]
# ## Vizualization of learned P

# %%
P = np.load('../../gptfnn/P.npy')

# %%
imgs = x_tr.dot(P.T) / 3
imgs[imgs < -1] = -1
imgs[imgs > 1] = 1

# %%
labels = scaler_y.inverse_transform(y_tr).astype(int)

# %%
pca = PCA(n_components=2)
x_2d = pca.fit_transform(x_tr)

# %%
plt.clf()
plt.figure(figsize=(15, 5))
zeros = imgs[labels == 0]
ones = imgs[labels == 1]
twos = imgs[labels == 2]
threes = imgs[labels == 3]
fours = imgs[labels == 4]
fives = imgs[labels == 5]
sixes = imgs[labels == 6]
sevens = imgs[labels == 7]
eights = imgs[labels == 8]
nines = imgs[labels == 9]

plt.subplot(1, 2, 1)
plt.plot(zeros[:, 0], zeros[:, 1], 'ro', label='0')
plt.plot(ones[:, 0], ones[:, 1], 'rs', label='1')
plt.plot(twos[:, 0], twos[:, 1], 'r*', label='2')
plt.plot(threes[:, 0], threes[:, 1], 'go', label='3')
plt.plot(fours[:, 0], fours[:, 1], 'gs', label='4')
plt.plot(fives[:, 0], fives[:, 1], 'g*', label='5')
plt.plot(sixes[:, 0], sixes[:, 1], 'bo', label='6')
plt.plot(sevens[:, 0], sevens[:, 1], 'bs', label='7')
plt.plot(eights[:, 0], eights[:, 1], 'b*', label='8')
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')
plt.legend(loc=(-0.25, 0))
plt.title('GP')

plt.subplot(1, 2, 2)
zeros = x_2d[labels == 0]
ones = x_2d[labels == 1]
twos = x_2d[labels == 2]
threes = x_2d[labels == 3]
fours = x_2d[labels == 4]
fives = x_2d[labels == 5]
sixes = x_2d[labels == 6]
sevens = x_2d[labels == 7]
eights = x_2d[labels == 8]
nines = x_2d[labels == 9]
plt.plot(zeros[:, 0], zeros[:, 1], 'ro', label='0')
plt.plot(ones[:, 0], ones[:, 1], 'rs', label='1')
plt.plot(twos[:, 0], twos[:, 1], 'r*', label='2')
plt.plot(threes[:, 0], threes[:, 1], 'go', label='3')
plt.plot(fours[:, 0], fours[:, 1], 'gs', label='4')
plt.plot(fives[:, 0], fives[:, 1], 'g*', label='5')
plt.plot(sixes[:, 0], sixes[:, 1], 'bo', label='6')
plt.plot(sevens[:, 0], sevens[:, 1], 'bs', label='7')
plt.plot(eights[:, 0], eights[:, 1], 'b*', label='8')
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')
plt.title('PCA')
# plt.legend(loc=(-0.25, 0))

# %% [markdown]
# Let's look at the embedding learned by the neural net

# %%
W1 = np.load('weights/W1.npy')
W2 = np.load('weights/W2.npy')
W3 = np.load('weights/W3.npy')
b1 = np.load('weights/b1.npy')
b2 = np.load('weights/b2.npy')

# %%
y_te = np.load('data_class/y_te.npy')
x_te = np.load('data_class/x_te.npy')
y_tr = np.load('data_class/y_tr.npy')
x_tr = np.load('data_class/x_tr.npy')

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
layer_1 = sigmoid(x_tr.dot(W1) + b1)
layer_2 = sigmoid(layer_1.dot(W2) + b2)
layer_3 = layer_2.dot(W3)
imgs = layer_3

scaler = StandardScaler()
imgs = scaler.fit_transform(imgs)
imgs /= 3

imgs[imgs < -1] = -1
imgs[imgs > 1] = 1

# %%
# labels = scaler_y.inverse_transform(y_tr).astype(int)
labels = y_tr

# %%
plt.clf()
plt.figure(figsize=(5, 4))
zeros = imgs[labels == 0]
ones = imgs[labels == 1]
twos = imgs[labels == 2]
threes = imgs[labels == 3]
fours = imgs[labels == 4]
fives = imgs[labels == 5]
sixes = imgs[labels == 6]
sevens = imgs[labels == 7]
eights = imgs[labels == 8]
nines = imgs[labels == 9]

plt.plot(zeros[:, 0], zeros[:, 1], 'ro', label='0')
plt.plot(ones[:, 0], ones[:, 1], 'rs', label='1')
plt.plot(twos[:, 0], twos[:, 1], 'r*', label='2')
plt.plot(threes[:, 0], threes[:, 1], 'go', label='3')
plt.plot(fours[:, 0], fours[:, 1], 'gs', label='4')
plt.plot(fives[:, 0], fives[:, 1], 'g*', label='5')
plt.plot(sixes[:, 0], sixes[:, 1], 'bo', label='6')
plt.plot(sevens[:, 0], sevens[:, 1], 'bs', label='7')
plt.plot(eights[:, 0], eights[:, 1], 'b*', label='8')
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')
plt.legend(loc=(-0.3, 0))



# plt.title('GP-NN-class')
plt.savefig('embedding_ttgp.eps',bbox_inches='tight')

# %%
plt.clf()
plt.figure(figsize=(12, 4))
zeros = imgs[labels == 0]
ones = imgs[labels == 1]
twos = imgs[labels == 2]
threes = imgs[labels == 3]
fours = imgs[labels == 4]
fives = imgs[labels == 5]
sixes = imgs[labels == 6]
sevens = imgs[labels == 7]
eights = imgs[labels == 8]
nines = imgs[labels == 9]

plt.subplot(1, 2, 1)
plt.plot(zeros[:, 0], zeros[:, 1], 'ro', label='0')
plt.plot(ones[:, 0], ones[:, 1], 'rs', label='1')
plt.plot(twos[:, 0], twos[:, 1], 'r*', label='2')
plt.plot(threes[:, 0], threes[:, 1], 'go', label='3')
plt.plot(fours[:, 0], fours[:, 1], 'gs', label='4')
plt.plot(fives[:, 0], fives[:, 1], 'g*', label='5')
plt.plot(sixes[:, 0], sixes[:, 1], 'bo', label='6')
plt.plot(sevens[:, 0], sevens[:, 1], 'bs', label='7')
plt.plot(eights[:, 0], eights[:, 1], 'b*', label='8')
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')
plt.legend(loc=(-0.3, 0))


plt.subplot(1, 2, 1)
imgs = encoder.predict(x_tr)
labels = y_tr

zeros = imgs[labels == 0]
ones = imgs[labels == 1]
twos = imgs[labels == 2]
threes = imgs[labels == 3]
fours = imgs[labels == 4]
fives = imgs[labels == 5]
sixes = imgs[labels == 6]
sevens = imgs[labels == 7]
eights = imgs[labels == 8]
nines = imgs[labels == 9]

plt.subplot(1, 2, 2)
plt.plot(zeros[:, 0], zeros[:, 1], 'ro', label='0')
plt.plot(ones[:, 0], ones[:, 1], 'rs', label='1')
plt.plot(twos[:, 0], twos[:, 1], 'r*', label='2')
plt.plot(threes[:, 0], threes[:, 1], 'go', label='3')
plt.plot(fours[:, 0], fours[:, 1], 'gs', label='4')
plt.plot(fives[:, 0], fives[:, 1], 'g*', label='5')
plt.plot(sixes[:, 0], sixes[:, 1], 'bo', label='6')
plt.plot(sevens[:, 0], sevens[:, 1], 'bs', label='7')
plt.plot(eights[:, 0], eights[:, 1], 'b*', label='8')
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')

# plt.title('GP-NN-class')
plt.savefig('embedding.eps',bbox_inches='tight')

# %%
np.where(nines[:, 0]>=-0.1)
# Out:
# (array([ 6, 71]),)

# %%
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')
plt.plot(eights[:, 0], eights[:, 1], 'b*', label='8')
plt.plot(nines[71, 0], nines[71, 1], 'ro', label='9')

# %%
img = x_tr[labels==9][71, :]
img *= scaler_x.std_
img += scaler_x.mean_
plt.imshow(img.reshape(8, 8), cmap='gray', interpolation='Nearest')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-a1722808e0f0> in <module>()
#       1 img = x_tr[labels==9][71, :]
# ----> 2 img *= scaler_x.std_
#       3 img += scaler_x.mean_
#       4 plt.imshow(img.reshape(8, 8), cmap='gray', interpolation='Nearest')
#
# NameError: name 'scaler_x' is not defined

# %% [markdown]
# ### Test

# %%
layer_1 = sigmoid(x_te.dot(W1) + b1)
layer_2 = sigmoid(layer_1.dot(W2) + b2)
layer_3 = layer_2.dot(W3)
imgs = layer_3

scaler = StandardScaler()
imgs = scaler.fit_transform(imgs)
imgs /= 3

imgs[imgs < -1] = -1
imgs[imgs > 1] = 1

labels = y_te

# %%
plt.clf()
plt.figure(figsize=(25, 10))
zeros = imgs[labels == 0]
ones = imgs[labels == 1]
twos = imgs[labels == 2]
threes = imgs[labels == 3]
fours = imgs[labels == 4]
fives = imgs[labels == 5]
sixes = imgs[labels == 6]
sevens = imgs[labels == 7]
eights = imgs[labels == 8]
nines = imgs[labels == 9]

plt.subplot(1, 2, 1)
plt.plot(zeros[:, 0], zeros[:, 1], 'ro', label='0')
plt.plot(ones[:, 0], ones[:, 1], 'rs', label='1')
plt.plot(twos[:, 0], twos[:, 1], 'r*', label='2')
plt.plot(threes[:, 0], threes[:, 1], 'go', label='3')
plt.plot(fours[:, 0], fours[:, 1], 'gs', label='4')
plt.plot(fives[:, 0], fives[:, 1], 'g*', label='5')
plt.plot(sixes[:, 0], sixes[:, 1], 'bo', label='6')
plt.plot(sevens[:, 0], sevens[:, 1], 'bs', label='7')
plt.plot(eights[:, 0], eights[:, 1], 'b*', label='8')
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')
plt.legend(loc=(-0.25, 0))
plt.title('GP-NN-class')

# %% [markdown]
# ## DNN

# %%
import keras
from keras.layers import Input, Dense
from keras.models import Model
from sklearn.metrics import accuracy_score
# Out:
# Using TensorFlow backend.

# %%
input_img = Input(shape=(64,))
l1 = Dense(50, activation='sigmoid')(input_img)
# l2 = Dense(50, activation='sigmoid')(l1)
encoded = Dense(2, activation='sigmoid')(l1)
l3 = Dense(50, activation='sigmoid')(encoded)
output = Dense(10, activation='softmax')(l3)
encoder = Model(input_img, encoded)
net = Model(input_img, output)

# %%
net.compile(optimizer='adam', loss='categorical_crossentropy', lr=1e3)
net.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                3250
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 102
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                150
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                510
# =================================================================
# Total params: 4,012
# Trainable params: 4,012
# Non-trainable params: 0
# _________________________________________________________________

# %%
net.fit(x_tr, keras.utils.np_utils.to_categorical(y_tr, 10), 
        nb_epoch=100, batch_size=50, shuffle=True, 
        validation_data=(x_te, keras.utils.np_utils.to_categorical(y_te, 10)))
# Out:
# Train on 1437 samples, validate on 360 samples
# Epoch 1/100
# 1437/1437 [==============================] - 0s - loss: 0.9074 - val_loss: 1.2371
# Epoch 2/100
# 1437/1437 [==============================] - 0s - loss: 0.8970 - val_loss: 1.2274
# Epoch 3/100
# 1437/1437 [==============================] - 0s - loss: 0.8888 - val_loss: 1.2208
# Epoch 4/100
# 1437/1437 [==============================] - 0s - loss: 0.8788 - val_loss: 1.2101
# Epoch 5/100
# 1437/1437 [==============================] - 0s - loss: 0.8705 - val_loss: 1.1985
# Epoch 6/100
# 1437/1437 [==============================] - 0s - loss: 0.8593 - val_loss: 1.1803
# Epoch 7/100
# 1437/1437 [==============================] - 0s - loss: 0.8498 - val_loss: 1.1705
# Epoch 8/100
# 1437/1437 [==============================] - 0s - loss: 0.8404 - val_loss: 1.1636
# Epoch 9/100
# 1437/1437 [==============================] - 0s - loss: 0.8312 - val_loss: 1.1517
# Epoch 10/100
# 1437/1437 [==============================] - 0s - loss: 0.8224 - val_loss: 1.1400
# Epoch 11/100
# 1437/1437 [==============================] - 0s - loss: 0.8127 - val_loss: 1.1361
# Epoch 12/100
# 1437/1437 [==============================] - 0s - loss: 0.8041 - val_loss: 1.1269
# Epoch 13/100
# 1437/1437 [==============================] - 0s - loss: 0.7947 - val_loss: 1.1257
# Epoch 14/100
# 1437/1437 [==============================] - 0s - loss: 0.7856 - val_loss: 1.1120
# Epoch 15/100
# 1437/1437 [==============================] - 0s - loss: 0.7767 - val_loss: 1.1019
# Epoch 16/100
# 1437/1437 [==============================] - 0s - loss: 0.7670 - val_loss: 1.0986
# Epoch 17/100
# 1437/1437 [==============================] - 0s - loss: 0.7569 - val_loss: 1.0938
# Epoch 18/100
# 1437/1437 [==============================] - 0s - loss: 0.7493 - val_loss: 1.0847
# Epoch 19/100
# 1437/1437 [==============================] - 0s - loss: 0.7418 - val_loss: 1.0750
# Epoch 20/100
# 1437/1437 [==============================] - 0s - loss: 0.7327 - val_loss: 1.0747
# Epoch 21/100
# 1437/1437 [==============================] - 0s - loss: 0.7236 - val_loss: 1.0744
# Epoch 22/100
# 1437/1437 [==============================] - 0s - loss: 0.7146 - val_loss: 1.0659
# Epoch 23/100
# 1437/1437 [==============================] - 0s - loss: 0.7065 - val_loss: 1.0581
# Epoch 24/100
# 1437/1437 [==============================] - 0s - loss: 0.6988 - val_loss: 1.0566
# Epoch 25/100
# 1437/1437 [==============================] - 0s - loss: 0.6902 - val_loss: 1.0473
# Epoch 26/100
# 1437/1437 [==============================] - 0s - loss: 0.6823 - val_loss: 1.0445
# Epoch 27/100
# 1437/1437 [==============================] - 0s - loss: 0.6736 - val_loss: 1.0349
# Epoch 28/100
# 1437/1437 [==============================] - 0s - loss: 0.6641 - val_loss: 1.0370
# Epoch 29/100
# 1437/1437 [==============================] - 0s - loss: 0.6561 - val_loss: 1.0258
# Epoch 30/100
# 1437/1437 [==============================] - 0s - loss: 0.6485 - val_loss: 1.0225
# Epoch 31/100
# 1437/1437 [==============================] - 0s - loss: 0.3177 - val_loss: 1.0322
# Epoch 95/100
# 1437/1437 [==============================] - 0s - loss: 0.3094 - val_loss: 1.0260
# Epoch 96/100
# 1437/1437 [==============================] - 0s - loss: 0.3033 - val_loss: 1.0286
# Epoch 97/100
# 1437/1437 [==============================] - 0s - loss: 0.2981 - val_loss: 1.0335
# Epoch 98/100
# 1437/1437 [==============================] - 0s - loss: 0.2935 - val_loss: 1.0307
# Epoch 99/100
# 1437/1437 [==============================] - 0s - loss: 0.2893 - val_loss: 1.0265
# Epoch 100/100
# 1437/1437 [==============================] - 0s - loss: 0.2850 - val_loss: 1.0332
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/IPython/kernel/__main__.py:3: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   app.launch_new_instance()

# %%
imgs = encoder.predict(x_tr)
labels = y_tr

# %%
plt.clf()
plt.figure(figsize=(5, 4))
zeros = imgs[labels == 0]
ones = imgs[labels == 1]
twos = imgs[labels == 2]
threes = imgs[labels == 3]
fours = imgs[labels == 4]
fives = imgs[labels == 5]
sixes = imgs[labels == 6]
sevens = imgs[labels == 7]
eights = imgs[labels == 8]
nines = imgs[labels == 9]

# plt.subplot(1, 2, 1)
plt.plot(zeros[:, 0], zeros[:, 1], 'ro', label='0')
plt.plot(ones[:, 0], ones[:, 1], 'rs', label='1')
plt.plot(twos[:, 0], twos[:, 1], 'r*', label='2')
plt.plot(threes[:, 0], threes[:, 1], 'go', label='3')
plt.plot(fours[:, 0], fours[:, 1], 'gs', label='4')
plt.plot(fives[:, 0], fives[:, 1], 'g*', label='5')
plt.plot(sixes[:, 0], sixes[:, 1], 'bo', label='6')
plt.plot(sevens[:, 0], sevens[:, 1], 'bs', label='7')
plt.plot(eights[:, 0], eights[:, 1], 'b*', label='8')
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')
# plt.legend(loc=(-0.25, 0))
plt.savefig('embedding_dnn.eps',bbox_inches='tight')

# %%
pred = net.predict(x_te)

# %%
pred = net.predict(x_te)

# %%
 accuracy_score(y_te, np.argmax(pred, axis=1))
# Out:
# 0.73888888888888893

# %% [markdown]
# ## Autoencoder

# %%
import keras
from keras.layers import Input, Dense
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
encoding_dim = 2
input_img = Input(shape=(64,))
# l1 = Dense(50, activation='sigmoid')(input_img)
# l2 = Dense(50, activation='sigmoid')(l1)
# encoded = Dense(encoding_dim, activation='sigmoid')(l2)
# decode_l1 = Dense(50, activation='sigmoid')(encoded)
# decode_l2 = Dense(50, activation='sigmoid')(decode_l1)
# decoded = Dense(64, activation='sigmoid')(decode_l2)

# l1 = Dense(50, activation='sigmoid')(input_img)
encoded = Dense(encoding_dim, activation='sigmoid')(input_img)
# decode_l1 = Dense(50, activation='sigmoid')(encoded)
decoded = Dense(64, activation='sigmoid')(encoded)

autoencoder = Model(input_img, decoded)
encoder = Model(input_img, encoded)

# %%
autoencoder.compile(optimizer='adam', loss='mse', lr=100.)
autoencoder.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_9 (InputLayer)             (None, 64)            0
# ____________________________________________________________________________________________________
# dense_27 (Dense)                 (None, 2)             130         input_9[0][0]
# ____________________________________________________________________________________________________
# dense_28 (Dense)                 (None, 64)            192         dense_27[0][0]
# ====================================================================================================
# Total params: 322
# ____________________________________________________________________________________________________

# %%
autoencoder.fit(x_tr, x_tr,
                nb_epoch=1000,
                batch_size=50,
                shuffle=True,
                validation_data=(x_te, x_te))
# Out:
# Train on 1437 samples, validate on 360 samples
# Epoch 1/1000
# 1437/1437 [==============================] - 0s - loss: 1.1959 - val_loss: 1.0538
# Epoch 464/1000
# 1437/1437 [==============================] - 0s - loss: 0.8614 - val_loss: 0.7196
# Epoch 465/1000
# 1437/1437 [==============================] - 0s - loss: 0.8614 - val_loss: 0.7197
# Epoch 466/1000
# 1437/1437 [==============================] - 0s - loss: 0.8613 - val_loss: 0.7196
# Epoch 467/1000
# 1437/1437 [==============================] - 0s - loss: 0.8613 - val_loss: 0.7196
# Epoch 468/1000
# 1437/1437 [==============================] - 0s - loss: 0.8612 - val_loss: 0.7195
# Epoch 469/1000
# 1437/1437 [==============================] - 0s - loss: 0.8612 - val_loss: 0.7194
# Epoch 470/1000
# 1437/1437 [==============================] - 0s - loss: 0.8611 - val_loss: 0.7195
# Epoch 471/1000
# 1437/1437 [==============================] - 0s - loss: 0.8611 - val_loss: 0.7194
# Epoch 472/1000
# 1437/1437 [==============================] - 0s - loss: 0.8610 - val_loss: 0.7194
# Epoch 473/1000
# 1437/1437 [==============================] - 0s - loss: 0.8610 - val_loss: 0.7194
# Epoch 474/1000
# 1437/1437 [==============================] - 0s - loss: 0.8609 - val_loss: 0.7193
# Epoch 475/1000
# 1437/1437 [==============================] - 0s - loss: 0.8609 - val_loss: 0.7193
# Epoch 476/1000
# 1437/1437 [==============================] - 0s - loss: 0.8608 - val_loss: 0.7192
# Epoch 477/1000
# 1437/1437 [==============================] - 0s - loss: 0.8608 - val_loss: 0.7192
# Epoch 478/1000
# 1437/1437 [==============================] - 0s - loss: 0.8608 - val_loss: 0.7192
# Epoch 479/1000
# 1437/1437 [==============================] - 0s - loss: 0.8607 - val_loss: 0.7191
# Epoch 480/1000
# 1437/1437 [==============================] - 0s - loss: 0.8606 - val_loss: 0.7191
# Epoch 481/1000
# 1437/1437 [==============================] - 0s - loss: 0.8606 - val_loss: 0.7191
# Epoch 482/1000
# 1437/1437 [==============================] - 0s - loss: 0.8606 - val_loss: 0.7190

# %%
imgs = encoder.predict(x_tr)
labels = y_tr

# %%
plt.clf()
plt.figure(figsize=(10, 10))
zeros = imgs[labels == 0]
ones = imgs[labels == 1]
twos = imgs[labels == 2]
threes = imgs[labels == 3]
fours = imgs[labels == 4]
fives = imgs[labels == 5]
sixes = imgs[labels == 6]
sevens = imgs[labels == 7]
eights = imgs[labels == 8]
nines = imgs[labels == 9]

# plt.subplot(1, 2, 1)
plt.plot(zeros[:, 0], zeros[:, 1], 'ro', label='0')
plt.plot(ones[:, 0], ones[:, 1], 'rs', label='1')
plt.plot(twos[:, 0], twos[:, 1], 'r*', label='2')
plt.plot(threes[:, 0], threes[:, 1], 'go', label='3')
plt.plot(fours[:, 0], fours[:, 1], 'gs', label='4')
plt.plot(fives[:, 0], fives[:, 1], 'g*', label='5')
plt.plot(sixes[:, 0], sixes[:, 1], 'bo', label='6')
plt.plot(sevens[:, 0], sevens[:, 1], 'bs', label='7')
plt.plot(eights[:, 0], eights[:, 1], 'b*', label='8')
plt.plot(nines[:, 0], nines[:, 1], 'ko', label='9')
plt.legend(loc=(-0.25, 0))
plt.title('GP-NN-class')
